# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from tqdm import tqdm
import random
from matplotlib import pyplot as plt # show graph
from sklearn.model_selection import GroupShuffleSplit
from nltk import word_tokenize,pos_tag
import warnings
warnings.filterwarnings('ignore')
from hmmlearn import hmm
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
# Out:
# C:\Users\omar mkkawy\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
import re
alphabets= "([A-Za-z])"
prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
suffixes = "(Inc|Ltd|Jr|Sr|Co)"
starters = "(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"
websites = "[.](com|net|org|io|gov)"
digits = "([0-9])"

def split_into_sentences(text):
    text = " " + text + "  "
    text = text.replace("\n"," ")
    text = re.sub(prefixes,"\\1<prd>",text)
    text = re.sub(websites,"<prd>\\1",text)
    text = re.sub(digits + "[.]" + digits,"\\1<prd>\\2",text)
    if "..." in text: text = text.replace("...","<prd><prd><prd>")
    if "Ph.D" in text: text = text.replace("Ph.D.","Ph<prd>D<prd>")
    text = re.sub("\s" + alphabets + "[.] "," \\1<prd> ",text)
    text = re.sub(acronyms+" "+starters,"\\1<stop> \\2",text)
    text = re.sub(alphabets + "[.]" + alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>\\3<prd>",text)
    text = re.sub(alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>",text)
    text = re.sub(" "+suffixes+"[.] "+starters," \\1<stop> \\2",text)
    text = re.sub(" "+suffixes+"[.]"," \\1<prd>",text)
    text = re.sub(" " + alphabets + "[.]"," \\1<prd>",text)
    if "”" in text: text = text.replace(".”","”.")
    if "\"" in text: text = text.replace(".\"","\".")
    if "!" in text: text = text.replace("!\"","\"!")
    if "?" in text: text = text.replace("?\"","\"?")
    text = text.replace(".",".<stop>")
    text = text.replace("?","?<stop>")
    text = text.replace("!","!<stop>")
    text = text.replace("<prd>",".")
    sentences = text.split("<stop>")
    sentences = sentences[:-1]
    sentences = [s.strip() for s in sentences]
    return sentences

# %%
import io
with io.open('harryp.txt','r',encoding='utf8') as f:
    txt = f.read()

# %%
# Split text into sentences
sentences = split_into_sentences(txt)

# Create DataFrame with sentences
df = pd.DataFrame({'sentence': sentences})

# POS tagging
dic1 = {'sentence': [], 'word': [], 'pos': []}
for i in range(df.shape[0]):
    text = word_tokenize(df['sentence'].iloc[i])
    for word, pos in pos_tag(text):
        dic1['sentence'].append(i)
        dic1['word'].append(word)
        dic1['pos'].append(pos)

# Create DataFrame with POS tagging results
df2 = pd.DataFrame(dic1)
df2.head()
# Out:
#    sentence     word  pos
# 0         0       Mr  NNP
# 1         0      and   CC
# 2         0      Mrs  NNP
# 3         0  Dursley  NNP
# 4         0        ,    ,

# %%
data = pd.read_csv("words_pos1.csv" , encoding='latin1' , index_col=[0])
data.head()
# Out:
#    sentence     word  pos
# 0         0       Mr  NNP
# 1         0      and   CC
# 2         0      Mrs  NNP
# 3         0  Dursley  NNP
# 4         0        ,    ,

# %%
tags = list(set(data.pos.values)) #Read POS values
words = list(set(data.word.values))
len(tags), len(words)
# Out:
# (38, 857)

# %%
y = data.pos
X = data.drop('pos', axis=1)

gs = GroupShuffleSplit(n_splits=2, test_size=.33, random_state=42)
train_ix, test_ix = next(gs.split(X, y, groups=data['sentence']))

data_train = data.loc[train_ix]
data_test = data.loc[test_ix]

data_train
# Out:
#       sentence      word  pos
# 0            0        Mr  NNP
# 1            0       and   CC
# 2            0       Mrs  NNP
# 3            0   Dursley  NNP
# 4            0         ,    ,
# ...        ...       ...  ...
# 3070       207    Flocks  NNS
# 3071       207        of   IN
# 3072       207      owls   NN
# 3073       210  shooting  VBG
# 3074       210     stars  NNS
#
# [2099 rows x 3 columns]

# %%
data_test
# Out:
#       sentence         word  pos
# 54           2           Mr  NNP
# 55           2      Dursley  NNP
# 56           2          was  VBD
# 57           2          the   DT
# 58           2     director   NN
# ...        ...          ...  ...
# 3061       205     Dursleys  NNP
# 3062       205          â  NNP
# 3063       205         dark   JJ
# 3064       205  living-room   NN
# 3065       205       window   NN
#
# [976 rows x 3 columns]

# %%
tags = list(set(data_train.pos.values)) #Read POS values
words = list(set(data_train.word.values))
len(tags), len(words)
# Out:
# (36, 673)

# %%
dfupdate = data_train.sample(frac=.15, replace=False, random_state=42)
dfupdate.word = 'UNKNOWN'
data_train.update(dfupdate)
words = list(set(data_train.word.values))
# Convert words and tags into numbers
word2id = {w: i for i, w in enumerate(words)}
tag2id = {t: i for i, t in enumerate(tags)}
id2tag = {i: t for i, t in enumerate(tags)}
len(tags), len(words)
# Out:
# (36, 616)

# %%
count_tags = dict(data_train.pos.value_counts())
count_tags_to_words = data_train.groupby(['pos']).apply(lambda grp: grp.groupby('word')['pos'].count().to_dict()).to_dict()
count_init_tags = dict(data_train.groupby('sentence').first().pos.value_counts())

# TODO use panda solution
count_tags_to_next_tags = np.zeros((len(tags), len(tags)), dtype=int)
sentences = list(data_train.sentence)
pos = list(data_train.pos)
for i in range(len(sentences)) :
    if (i > 0) and (sentences[i] == sentences[i - 1]):
        prevtagid = tag2id[pos[i - 1]]
        nexttagid = tag2id[pos[i]]
        count_tags_to_next_tags[prevtagid][nexttagid] += 1

# %%
mystartprob = np.zeros((len(tags),))
mytransmat = np.zeros((len(tags), len(tags)))
myemissionprob = np.zeros((len(tags), len(words)))
num_sentences = sum(count_init_tags.values())
sum_tags_to_next_tags = np.sum(count_tags_to_next_tags, axis=1)
for tag, tagid in tag2id.items():
    floatCountTag = float(count_tags.get(tag, 0))
    mystartprob[tagid] = count_init_tags.get(tag, 0) / num_sentences
    for word, wordid in word2id.items():
        myemissionprob[tagid][wordid]= count_tags_to_words.get(tag, {}).get(word, 0) / floatCountTag
    for tag2, tagid2 in tag2id.items():
        mytransmat[tagid][tagid2]= count_tags_to_next_tags[tagid][tagid2] / sum_tags_to_next_tags[tagid]

# %%
model = hmm.CategoricalHMM(n_components=len(tags), algorithm='viterbi', random_state=42)
model.startprob_ = mystartprob
model.transmat_ = mytransmat
model.emissionprob_ = myemissionprob

# %%
data_test.loc[~data_test['word'].isin(words), 'word'] = 'UNKNOWN'
data_test.loc[~data_test['pos'].isin(tags),'pos'] = random.choice(tags)
#print(data_test)
word_test = list(data_test.word)
#print(word_test)
samples = []
for i, val in enumerate(word_test):
    samples.append([word2id[val]])
    ##print(i,val,samples)

# %%
# TODO use panda solution
lengths = []
count = 0
sentences = list(data_test.sentence)
for i in range(len(sentences)) :
    if (i > 0) and (sentences[i] == sentences[i - 1]):
        count += 1
    elif i > 0:
        lengths.append(count)
        count = 1
    else:
        count = 1
len(lengths),len(samples)
# Out:
# (58, 976)

# %%
# Convert samples to a 2D NumPy array
samples_2d = np.array(samples)

# Normalize the rows of the emissionprob_ matrix
emissionprob_normalized = model.emissionprob_ / model.emissionprob_.sum(axis=1, keepdims=True)
model.emissionprob_ = emissionprob_normalized

# Predict POS tags
pos_predict = model.predict(samples_2d, lengths)
pos_predict
# Out:
# array([ 7,  7, 11, 26, 12, 15, 26, 12, 32,  7, 21, 27, 11, 15, 26,  7, 22,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,  0,  9,  7, 10,
#         7,  7, 11, 24, 15, 26, 12, 21,  7,  7,  7,  7,  7, 21, 28, 11, 12,
#        15, 26, 12, 22, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35,  0, 16, 11, 15, 12, 21,  7,  7, 11, 24, 33, 12, 21,  7,  7,
#         7, 15, 26, 12, 21, 10, 11, 25,  7,  7, 21, 10,  7, 21, 15,  7, 11,
#         0, 15, 26, 12, 10, 11, 33, 12, 15, 26, 12,  7,  7,  7, 21,  7, 22,
#        35, 35, 35, 35, 35, 35,  0, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,  0, 35, 35, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35,  0, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35,  0,  7,  7, 11, 16, 26, 12, 21, 10, 11, 26, 12, 15,
#        15, 33, 12, 15, 16, 11, 15, 26, 31, 12, 15, 12, 21, 16,  2, 31, 17,
#        22, 35, 15,  0, 11, 25,  6, 26, 12, 15, 26, 31, 17, 15, 12, 15, 17,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,  0, 26, 12, 22, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35,  0, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35,  0,  7,  7, 21,  7, 21, 11, 26,  0, 31, 21, 33, 12, 16, 11,
#        15, 26, 31, 17, 16,  2, 31, 25,  6, 15, 26, 17, 15, 17, 15, 16, 11,
#        26, 12, 15, 16, 31, 25, 26, 12, 31, 12, 16, 11, 16, 26, 21, 16, 11,
#         8, 15, 35, 35, 35, 35, 35, 35, 35,  0, 16, 18,  6, 32, 15, 16, 11,
#        16, 26, 12, 12, 25,  6, 15, 12, 15, 22, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35,  0,  7,  7, 21,  7, 16, 11, 21, 15, 26, 12, 31, 12, 21, 10,
#         0, 11, 16, 11, 26, 31, 12, 15,  7,  7, 11, 15, 26, 12, 11,  8, 26,
#        31, 12, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,  0,
#        16, 11,  0,  8, 15, 33, 12, 12,  7,  7, 22,  7, 11,  7,  7,  7, 12,
#        25,  6, 16,  0, 21, 16, 11, 16, 15, 26, 12, 16, 11, 16, 15, 25,  6,
#        15,  7,  7,  2, 31, 12, 22, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35,  0,  7, 26, 12, 15, 16, 26, 12, 35,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35,  0, 16, 11, 26, 31, 16, 11,
#        33, 12, 15,  7,  7, 22, 35, 15, 26, 12, 15, 26, 12, 21,  7,  7,  7,
#         7,  7,  7,  7, 22,  7, 11,  7,  7,  7,  7, 21, 16,  0, 32, 16, 11,
#        12, 25,  6, 15, 33, 12,  7,  7,  7, 21, 33, 12, 15, 26, 12, 15, 16,
#        11, 21, 15, 22, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35,  0, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35, 35,  0,  7, 21, 33, 12, 21, 15, 16, 11, 16, 12, 16,
#         2, 31, 12,  6, 26, 12, 15, 26, 12, 15, 16, 11, 32, 25,  6, 15, 16,
#        11, 24, 15, 16, 11, 32, 25, 26, 12, 15, 12,  0, 21, 16,  2, 31, 17,
#        19, 16, 18,  6, 16, 26,  7, 11, 15, 26, 16,  2, 31, 12,  0,  0, 15,
#        12,  9, 26, 12, 12, 22, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,  0,
#        26, 12, 19, 31, 12, 21, 10, 33, 17, 15, 12, 15, 26, 12, 11,  0, 32,
#        32, 15,  7,  7, 16, 11,  8,  0, 31, 21, 26, 31, 12, 27, 11, 26, 12,
#        21, 10,  7, 21, 31, 17, 26, 12, 19, 31, 12, 11,  7,  7, 35, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35,  0, 16, 11, 16, 22, 35, 35, 35, 35,
#        35, 35, 35, 35, 35, 35,  0, 26, 31, 12, 12, 11, 24, 15, 26, 31, 12,
#        15, 12, 11, 24, 15, 33, 12,  0, 21,  0, 32,  7,  7, 21, 16,  2, 31,
#        12,  6, 32, 25,  6, 12, 27, 11,  8, 24, 15, 26, 12, 16,  2, 31, 12,
#        12, 15, 16, 21, 10, 11, 26, 12, 16, 11, 25, 16, 15, 16, 11, 32, 15,
#        26, 31, 12, 15,  3, 11,  8, 15, 12, 22, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35,  0,  7,  7, 12, 22, 35, 35, 35, 35, 35, 35, 35, 35,
#        35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,  0,  7,  7,  0, 21, 10,
#        31, 12,  8, 21, 26, 12, 21,  7, 16, 11, 15], dtype=int64)

# %%
predicted_sequence = []
for i in pos_predict:
    predicted_sequence.append(id2tag[i])

# %%
for x,y in zip(data_test['word'],predicted_sequence):
    print(("Word = "+str(x),"Predicted POS = "+str(y)))
# Out:
# ('Word = Mr', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = of', 'Predicted POS = IN')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = called', 'Predicted POS = VBN')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = which', 'Predicted POS = WDT')
# ('Word = made', 'Predicted POS = VBD')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = The', 'Predicted POS = DT')
# ('Word = Dursleys', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = to', "Predicted POS = ''")
# ('Word = think', "Predicted POS = ''")
# ('Word = what', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = would', "Predicted POS = ''")
# ('Word = say', "Predicted POS = ''")
# ('Word = if', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = Potters', "Predicted POS = ''")
# ('Word = arrived', "Predicted POS = ''")
# ('Word = in', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = street', 'Predicted POS = RB')
# ('Word = When', 'Predicted POS = WRB')
# ('Word = Mr', 'Predicted POS = NNP')
# ('Word = and', 'Predicted POS = CC')
# ('Word = Mrs', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = up', 'Predicted POS = RP')
# ('Word = on', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = there', 'Predicted POS = EX')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = nothing', 'Predicted POS = NN')
# ('Word = about', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = outside', "Predicted POS = ''")
# ('Word = to', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = that', "Predicted POS = ''")
# ('Word = strange', "Predicted POS = ''")
# ('Word = and', "Predicted POS = ''")
# ('Word = mysterious', "Predicted POS = ''")
# ('Word = things', "Predicted POS = ''")
# ('Word = would', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = be', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = all', "Predicted POS = ''")
# ('Word = over', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', 'Predicted POS = RB')
# ('Word = UNKNOWN', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = past', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = Mr', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = picked', 'Predicted POS = VBD')
# ('Word = up', 'Predicted POS = RP')
# ('Word = his', 'Predicted POS = PRP$')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = Mrs', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = on', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = and', 'Predicted POS = CC')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = to', 'Predicted POS = TO')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = Dudley', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = ,')
# ('Word = but', 'Predicted POS = CC')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = because', 'Predicted POS = IN')
# ('Word = Dudley', 'Predicted POS = NNP')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = now', 'Predicted POS = RB')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = and', 'Predicted POS = CC')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = his', 'Predicted POS = PRP$')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = at', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = â\x80\x9c', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = â\x80\x9d', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = Mr', "Predicted POS = ''")
# ('Word = Dursley', "Predicted POS = ''")
# ('Word = as', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = left', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', 'Predicted POS = RB')
# ('Word = It', "Predicted POS = ''")
# ('Word = was', "Predicted POS = ''")
# ('Word = on', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = corner', "Predicted POS = ''")
# ('Word = of', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = street', "Predicted POS = ''")
# ('Word = that', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = noticed', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = first', "Predicted POS = ''")
# ('Word = sign', "Predicted POS = ''")
# ('Word = of', "Predicted POS = ''")
# ('Word = something', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = â\x80\x94', "Predicted POS = ''")
# ('Word = a', "Predicted POS = ''")
# ('Word = cat', "Predicted POS = ''")
# ('Word = reading', "Predicted POS = ''")
# ('Word = a', "Predicted POS = ''")
# ('Word = map', 'Predicted POS = RB')
# ('Word = For', "Predicted POS = ''")
# ('Word = a', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = Mr', "Predicted POS = ''")
# ('Word = Dursley', "Predicted POS = ''")
# ('Word = didn', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = t', "Predicted POS = ''")
# ('Word = realize', "Predicted POS = ''")
# ('Word = what', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = had', "Predicted POS = ''")
# ('Word = seen', "Predicted POS = ''")
# ('Word = â\x80\x94', "Predicted POS = ''")
# ('Word = then', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = his', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = around', "Predicted POS = ''")
# ('Word = to', "Predicted POS = ''")
# ('Word = look', "Predicted POS = ''")
# ('Word = again', 'Predicted POS = RB')
# ('Word = As', "Predicted POS = ''")
# ('Word = Mr', "Predicted POS = ''")
# ('Word = Dursley', "Predicted POS = ''")
# ('Word = drove', "Predicted POS = ''")
# ('Word = around', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = corner', "Predicted POS = ''")
# ('Word = and', "Predicted POS = ''")
# ('Word = up', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = road', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = watched', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = cat', "Predicted POS = ''")
# ('Word = in', "Predicted POS = ''")
# ('Word = his', "Predicted POS = ''")
# ('Word = UNKNOWN', 'Predicted POS = RB')
# ('Word = Mr', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = gave', 'Predicted POS = VBD')
# ('Word = himself', 'Predicted POS = PRP')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = ,')
# ('Word = and', 'Predicted POS = CC')
# ('Word = put', 'Predicted POS = VBD')
# ('Word = the', 'Predicted POS = DT')
# ('Word = cat', 'Predicted POS = NN')
# ('Word = out', 'Predicted POS = IN')
# ('Word = of', 'Predicted POS = IN')
# ('Word = his', 'Predicted POS = PRP$')
# ('Word = mind', 'Predicted POS = NN')
# ('Word = As', 'Predicted POS = IN')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = sat', 'Predicted POS = VBD')
# ('Word = in', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = usual', 'Predicted POS = JJ')
# ('Word = morning', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = couldn', 'Predicted POS = VBZ')
# ('Word = â\x80\x99', 'Predicted POS = JJ')
# ('Word = t', 'Predicted POS = NNS')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = that', 'Predicted POS = IN')
# ('Word = there', 'Predicted POS = RB')
# ('Word = seemed', 'Predicted POS = VBD')
# ('Word = to', 'Predicted POS = TO')
# ('Word = be', 'Predicted POS = VB')
# ('Word = a', 'Predicted POS = DT')
# ('Word = lot', 'Predicted POS = NN')
# ('Word = of', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = JJ')
# ('Word = people', 'Predicted POS = NNS')
# ('Word = about', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = in', 'Predicted POS = IN')
# ('Word = cloaks', 'Predicted POS = NNS')
# ('Word = Mr', "Predicted POS = ''")
# ('Word = Dursley', "Predicted POS = ''")
# ('Word = couldn', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = t', "Predicted POS = ''")
# ('Word = bear', "Predicted POS = ''")
# ('Word = people', "Predicted POS = ''")
# ('Word = who', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = in', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = â\x80\x94', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = you', "Predicted POS = ''")
# ('Word = saw', "Predicted POS = ''")
# ('Word = on', "Predicted POS = ''")
# ('Word = young', "Predicted POS = ''")
# ('Word = people', "Predicted POS = ''")
# ('Word = !', "Predicted POS = ''")
# ('Word = He', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = this', "Predicted POS = ''")
# ('Word = was', "Predicted POS = ''")
# ('Word = some', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = UNKNOWN', 'Predicted POS = RB')
# ('Word = The', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = on', "Predicted POS = ''")
# ('Word = and', "Predicted POS = ''")
# ('Word = a', "Predicted POS = ''")
# ('Word = few', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = Mr', "Predicted POS = ''")
# ('Word = Dursley', "Predicted POS = ''")
# ('Word = arrived', "Predicted POS = ''")
# ('Word = in', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = lot', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = his', "Predicted POS = ''")
# ('Word = mind', "Predicted POS = ''")
# ('Word = back', "Predicted POS = ''")
# ('Word = on', "Predicted POS = ''")
# ('Word = UNKNOWN', 'Predicted POS = RB')
# ('Word = If', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = hadn', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = t', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = might', "Predicted POS = ''")
# ('Word = have', "Predicted POS = ''")
# ('Word = found', "Predicted POS = ''")
# ('Word = it', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = to', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = on', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = that', "Predicted POS = ''")
# ('Word = morning', 'Predicted POS = RB')
# ('Word = Mr', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = had', 'Predicted POS = VBD')
# ('Word = a', 'Predicted POS = DT')
# ('Word = perfectly', 'Predicted POS = RB')
# ('Word = normal', 'Predicted POS = JJ')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = UNKNOWN', 'Predicted POS = PRP$')
# ('Word = morning', 'Predicted POS = NN')
# ('Word = He', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = at', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = JJ')
# ('Word = people', 'Predicted POS = NNS')
# ('Word = He', 'Predicted POS = PRP')
# ('Word = â\x80\x99', 'Predicted POS = VBZ')
# ('Word = d', 'Predicted POS = JJ')
# ('Word = UNKNOWN', 'Predicted POS = TO')
# ('Word = all', 'Predicted POS = VB')
# ('Word = about', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = people', 'Predicted POS = NNS')
# ('Word = in', 'Predicted POS = IN')
# ('Word = cloaks', 'Predicted POS = NNS')
# ('Word = until', 'Predicted POS = IN')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = passed', 'Predicted POS = VBD')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = of', 'Predicted POS = IN')
# ('Word = them', 'Predicted POS = PRP')
# ('Word = next', 'Predicted POS = JJ')
# ('Word = to', 'Predicted POS = TO')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = â\x80\x99', 'Predicted POS = JJ')
# ('Word = s', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = him', 'Predicted POS = PRP')
# ('Word = no', 'Predicted POS = DT')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = being', 'Predicted POS = VBG')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = Potter', "Predicted POS = ''")
# ('Word = wasn', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = t', "Predicted POS = ''")
# ('Word = such', "Predicted POS = ''")
# ('Word = an', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = name', 'Predicted POS = RB')
# ('Word = It', 'Predicted POS = PRP')
# ('Word = might', 'Predicted POS = MD')
# ('Word = have', 'Predicted POS = VB')
# ('Word = been', 'Predicted POS = VBN')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = He', 'Predicted POS = PRP')
# ('Word = found', 'Predicted POS = VBD')
# ('Word = it', 'Predicted POS = PRP')
# ('Word = a', 'Predicted POS = DT')
# ('Word = lot', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = to', 'Predicted POS = TO')
# ('Word = UNKNOWN', 'Predicted POS = VB')
# ('Word = on', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = that', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = and', "Predicted POS = ''")
# ('Word = when', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = left', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = at', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = was', "Predicted POS = ''")
# ('Word = still', "Predicted POS = ''")
# ('Word = so', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = that', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = walked', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = into', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = just', "Predicted POS = ''")
# ('Word = outside', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', 'Predicted POS = RB')
# ('Word = â\x80\x9c', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = â\x80\x9d', 'Predicted POS = NNP')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = as', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = old', 'Predicted POS = JJ')
# ('Word = man', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = ,')
# ('Word = and', 'Predicted POS = CC')
# ('Word = almost', 'Predicted POS = RB')
# ('Word = fell', 'Predicted POS = VBD')
# ('Word = It', 'Predicted POS = PRP')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = a', 'Predicted POS = DT')
# ('Word = few', 'Predicted POS = JJ')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = before', 'Predicted POS = IN')
# ('Word = Mr', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = that', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = man', 'Predicted POS = NN')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = wearing', 'Predicted POS = VBG')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = JJ')
# ('Word = cloak', 'Predicted POS = NN')
# ('Word = He', "Predicted POS = ''")
# ('Word = didn', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = t', "Predicted POS = ''")
# ('Word = seem', "Predicted POS = ''")
# ('Word = at', "Predicted POS = ''")
# ('Word = all', "Predicted POS = ''")
# ('Word = upset', "Predicted POS = ''")
# ('Word = at', "Predicted POS = ''")
# ('Word = being', "Predicted POS = ''")
# ('Word = almost', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = to', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', 'Predicted POS = RB')
# ('Word = It', 'Predicted POS = PRP')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = now', 'Predicted POS = RB')
# ('Word = sitting', 'Predicted POS = VBG')
# ('Word = on', 'Predicted POS = IN')
# ('Word = his', 'Predicted POS = PRP$')
# ('Word = garden', 'Predicted POS = NN')
# ('Word = wall', 'Predicted POS = NN')
# ('Word = â\x80\x9c', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = !', 'Predicted POS = .')
# ('Word = â\x80\x9d', 'Predicted POS = NNP')
# ('Word = said', 'Predicted POS = VBD')
# ('Word = Mr', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = to', 'Predicted POS = TO')
# ('Word = UNKNOWN', 'Predicted POS = VB')
# ('Word = himself', 'Predicted POS = PRP')
# ('Word = together', 'Predicted POS = RB')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = himself', 'Predicted POS = PRP')
# ('Word = into', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = She', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = him', 'Predicted POS = PRP')
# ('Word = over', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = TO')
# ('Word = all', 'Predicted POS = VB')
# ('Word = about', 'Predicted POS = IN')
# ('Word = Mrs', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = VBZ')
# ('Word = â\x80\x99', 'Predicted POS = JJ')
# ('Word = s', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = with', "Predicted POS = ''")
# ('Word = her', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = and', "Predicted POS = ''")
# ('Word = how', "Predicted POS = ''")
# ('Word = Dudley', "Predicted POS = ''")
# ('Word = had', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = a', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = â\x80\x9c', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = t', "Predicted POS = ''")
# ('Word = !', "Predicted POS = ''")
# ('Word = â\x80\x9d', "Predicted POS = ''")
# ('Word = UNKNOWN', 'Predicted POS = RB')
# ('Word = â\x80\x9d', 'Predicted POS = NNP')
# ('Word = The', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = himself', 'Predicted POS = PRP')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = to', "Predicted POS = ''")
# ('Word = be', "Predicted POS = ''")
# ('Word = any', "Predicted POS = ''")
# ('Word = more', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = of', "Predicted POS = ''")
# ('Word = owls', "Predicted POS = ''")
# ('Word = tonight', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = ?', "Predicted POS = ''")
# ('Word = â\x80\x9d', "Predicted POS = ''")
# ('Word = â\x80\x9c', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = â\x80\x9d', "Predicted POS = ''")
# ('Word = said', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = â\x80\x9c', "Predicted POS = ''")
# ('Word = I', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = t', "Predicted POS = ''")
# ('Word = know', "Predicted POS = ''")
# ('Word = about', "Predicted POS = ''")
# ('Word = that', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = but', "Predicted POS = ''")
# ('Word = it', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = s', "Predicted POS = ''")
# ('Word = not', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = owls', "Predicted POS = ''")
# ('Word = that', "Predicted POS = ''")
# ('Word = have', "Predicted POS = ''")
# ('Word = been', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = today', 'Predicted POS = RB')
# ('Word = It', 'Predicted POS = PRP')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = no', 'Predicted POS = DT')
# ('Word = good', 'Predicted POS = JJ')
# ('Word = He', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = his', 'Predicted POS = PRP$')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = â\x80\x9c', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ?', 'Predicted POS = .')
# ('Word = â\x80\x9d', "Predicted POS = ''")
# ('Word = â\x80\x9c', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = on', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = news', 'Predicted POS = NN')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = â\x80\x9d', 'Predicted POS = NNP')
# ('Word = Mr', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = â\x80\x9d', 'Predicted POS = NNP')
# ('Word = â\x80\x9c', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ?', 'Predicted POS = .')
# ('Word = â\x80\x9d', 'Predicted POS = NNP')
# ('Word = snapped', 'Predicted POS = VBD')
# ('Word = Mrs', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = â\x80\x9c', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = I', 'Predicted POS = PRP')
# ('Word = just', 'Predicted POS = RB')
# ('Word = thought', 'Predicted POS = VBN')
# ('Word = it', 'Predicted POS = PRP')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = something', 'Predicted POS = NN')
# ('Word = to', 'Predicted POS = TO')
# ('Word = do', 'Predicted POS = VB')
# ('Word = with', 'Predicted POS = IN')
# ('Word = her', 'Predicted POS = PRP$')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = â\x80\x9d', 'Predicted POS = NNP')
# ('Word = Mrs', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = ,')
# ('Word = her', 'Predicted POS = PRP$')
# ('Word = tea', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = said', 'Predicted POS = VBD')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = as', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = as', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = could', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = â\x80\x9c', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = son', "Predicted POS = ''")
# ('Word = â\x80\x94', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = d', "Predicted POS = ''")
# ('Word = be', "Predicted POS = ''")
# ('Word = about', "Predicted POS = ''")
# ('Word = Dudley', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = s', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = now', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = t', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = ?', "Predicted POS = ''")
# ('Word = â\x80\x9d', "Predicted POS = ''")
# ('Word = â\x80\x9c', "Predicted POS = ''")
# ('Word = I', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = so', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = â\x80\x9d', "Predicted POS = ''")
# ('Word = said', "Predicted POS = ''")
# ('Word = Mrs', "Predicted POS = ''")
# ('Word = Dursley', "Predicted POS = ''")
# ('Word = UNKNOWN', 'Predicted POS = RB')
# ('Word = â\x80\x9c', "Predicted POS = ''")
# ('Word = What', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = s', "Predicted POS = ''")
# ('Word = his', "Predicted POS = ''")
# ('Word = name', "Predicted POS = ''")
# ('Word = again', "Predicted POS = ''")
# ('Word = ?', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = â\x80\x99', "Predicted POS = ''")
# ('Word = t', "Predicted POS = ''")
# ('Word = it', "Predicted POS = ''")
# ('Word = ?', "Predicted POS = ''")
# ('Word = â\x80\x9d', "Predicted POS = ''")
# ('Word = â\x80\x9c', "Predicted POS = ''")
# ('Word = Harry', 'Predicted POS = RB')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = UNKNOWN', 'Predicted POS = PRP$')
# ('Word = name', 'Predicted POS = NN')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = if', 'Predicted POS = IN')
# ('Word = you', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = me', 'Predicted POS = PRP')
# ('Word = â\x80\x9d', 'Predicted POS = NN')
# ('Word = He', 'Predicted POS = PRP')
# ('Word = didn', 'Predicted POS = VBZ')
# ('Word = â\x80\x99', 'Predicted POS = JJ')
# ('Word = t', 'Predicted POS = NN')
# ('Word = say', 'Predicted POS = VB')
# ('Word = another', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = on', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = as', 'Predicted POS = IN')
# ('Word = they', 'Predicted POS = PRP')
# ('Word = went', 'Predicted POS = VBD')
# ('Word = UNKNOWN', 'Predicted POS = VBN')
# ('Word = to', 'Predicted POS = TO')
# ('Word = UNKNOWN', 'Predicted POS = VB')
# ('Word = if', 'Predicted POS = IN')
# ('Word = it', 'Predicted POS = PRP')
# ('Word = got', 'Predicted POS = VBD')
# ('Word = out', 'Predicted POS = RP')
# ('Word = that', 'Predicted POS = IN')
# ('Word = they', 'Predicted POS = PRP')
# ('Word = were', 'Predicted POS = VBD')
# ('Word = UNKNOWN', 'Predicted POS = VBN')
# ('Word = to', 'Predicted POS = TO')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = of', 'Predicted POS = IN')
# ('Word = â\x80\x94', 'Predicted POS = NN')
# ('Word = well', 'Predicted POS = RB')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = didn', 'Predicted POS = VBZ')
# ('Word = â\x80\x99', 'Predicted POS = JJ')
# ('Word = t', 'Predicted POS = NNS')
# ('Word = think', 'Predicted POS = VBP')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = could', 'Predicted POS = MD')
# ('Word = bear', 'Predicted POS = VB')
# ('Word = it', 'Predicted POS = PRP')
# ('Word = The', 'Predicted POS = DT')
# ('Word = Dursleys', 'Predicted POS = NNP')
# ('Word = got', 'Predicted POS = VBD')
# ('Word = into', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = DT')
# ('Word = It', 'Predicted POS = PRP')
# ('Word = didn', 'Predicted POS = VBZ')
# ('Word = â\x80\x99', 'Predicted POS = JJ')
# ('Word = t', 'Predicted POS = NN')
# ('Word = so', 'Predicted POS = RB')
# ('Word = much', 'Predicted POS = RB')
# ('Word = as', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = when', 'Predicted POS = WRB')
# ('Word = a', 'Predicted POS = DT')
# ('Word = car', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = on', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = next', "Predicted POS = ''")
# ('Word = street', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = when', "Predicted POS = ''")
# ('Word = two', "Predicted POS = ''")
# ('Word = owls', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = overhead', 'Predicted POS = RB')
# ('Word = The', 'Predicted POS = DT')
# ('Word = cat', 'Predicted POS = NN')
# ('Word = â\x80\x99', 'Predicted POS = VBP')
# ('Word = s', 'Predicted POS = JJ')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = ,')
# ('Word = and', 'Predicted POS = CC')
# ('Word = its', 'Predicted POS = PRP$')
# ('Word = eyes', 'Predicted POS = NNS')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = like', 'Predicted POS = IN')
# ('Word = this', 'Predicted POS = DT')
# ('Word = man', 'Predicted POS = NN')
# ('Word = had', 'Predicted POS = VBD')
# ('Word = ever', 'Predicted POS = RB')
# ('Word = been', 'Predicted POS = VBN')
# ('Word = seen', 'Predicted POS = VBN')
# ('Word = on', 'Predicted POS = IN')
# ('Word = Privet', 'Predicted POS = NNP')
# ('Word = Drive', 'Predicted POS = NNP')
# ('Word = He', 'Predicted POS = PRP')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = wearing', 'Predicted POS = VBG')
# ('Word = long', 'Predicted POS = RB')
# ('Word = UNKNOWN', 'Predicted POS = JJ')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = JJ')
# ('Word = cloak', 'Predicted POS = NN')
# ('Word = that', 'Predicted POS = WDT')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = and', 'Predicted POS = CC')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = UNKNOWN', 'Predicted POS = JJ')
# ('Word = boots', 'Predicted POS = NNS')
# ('Word = This', 'Predicted POS = DT')
# ('Word = man', 'Predicted POS = NN')
# ('Word = â\x80\x99', 'Predicted POS = VBP')
# ('Word = s', 'Predicted POS = JJ')
# ('Word = name', 'Predicted POS = NN')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = Albus', 'Predicted POS = NNP')
# ('Word = Dumbledore', 'Predicted POS = NNP')
# ('Word = â\x80\x9d', "Predicted POS = ''")
# ('Word = He', "Predicted POS = ''")
# ('Word = found', "Predicted POS = ''")
# ('Word = what', "Predicted POS = ''")
# ('Word = he', "Predicted POS = ''")
# ('Word = was', "Predicted POS = ''")
# ('Word = looking', "Predicted POS = ''")
# ('Word = for', "Predicted POS = ''")
# ('Word = in', "Predicted POS = ''")
# ('Word = his', "Predicted POS = ''")
# ('Word = inside', "Predicted POS = ''")
# ('Word = UNKNOWN', 'Predicted POS = RB')
# ('Word = He', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = it', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = ,', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = it', "Predicted POS = ''")
# ('Word = up', "Predicted POS = ''")
# ('Word = in', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = ,', "Predicted POS = ''")
# ('Word = and', "Predicted POS = ''")
# ('Word = clicked', "Predicted POS = ''")
# ('Word = it', 'Predicted POS = RB')
# ('Word = The', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = JJ')
# ('Word = street', 'Predicted POS = NN')
# ('Word = lamp', 'Predicted POS = NN')
# ('Word = went', 'Predicted POS = VBD')
# ('Word = out', 'Predicted POS = RP')
# ('Word = with', 'Predicted POS = IN')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = JJ')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = If', 'Predicted POS = IN')
# ('Word = anyone', 'Predicted POS = NN')
# ('Word = looked', 'Predicted POS = VBD')
# ('Word = out', 'Predicted POS = RP')
# ('Word = of', 'Predicted POS = IN')
# ('Word = their', 'Predicted POS = PRP$')
# ('Word = window', 'Predicted POS = NN')
# ('Word = now', 'Predicted POS = RB')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = even', 'Predicted POS = RB')
# ('Word = UNKNOWN', 'Predicted POS = VBN')
# ('Word = Mrs', 'Predicted POS = NNP')
# ('Word = Dursley', 'Predicted POS = NNP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = they', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBZ')
# ('Word = â\x80\x99', 'Predicted POS = JJ')
# ('Word = t', 'Predicted POS = NN')
# ('Word = be', 'Predicted POS = VB')
# ('Word = UNKNOWN', 'Predicted POS = VBN')
# ('Word = to', 'Predicted POS = TO')
# ('Word = see', 'Predicted POS = VB')
# ('Word = anything', 'Predicted POS = NN')
# ('Word = that', 'Predicted POS = WDT')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = UNKNOWN', 'Predicted POS = VBG')
# ('Word = down', 'Predicted POS = RP')
# ('Word = on', 'Predicted POS = IN')
# ('Word = the', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = He', 'Predicted POS = PRP')
# ('Word = didn', 'Predicted POS = VBZ')
# ('Word = â\x80\x99', 'Predicted POS = JJ')
# ('Word = t', 'Predicted POS = NN')
# ('Word = look', 'Predicted POS = NN')
# ('Word = at', 'Predicted POS = IN')
# ('Word = it', 'Predicted POS = PRP')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = but', 'Predicted POS = CC')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = VBD')
# ('Word = to', 'Predicted POS = TO')
# ('Word = it', 'Predicted POS = PRP')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = he', 'Predicted POS = PRP')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = UNKNOWN', 'Predicted POS = VBN')
# ('Word = at', 'Predicted POS = IN')
# ('Word = a', 'Predicted POS = DT')
# ('Word = UNKNOWN', 'Predicted POS = JJ')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = who', 'Predicted POS = WP')
# ('Word = was', 'Predicted POS = VBD')
# ('Word = wearing', 'Predicted POS = VBG')
# ('Word = UNKNOWN', 'Predicted POS = IN')
# ('Word = UNKNOWN', 'Predicted POS = NN')
# ('Word = UNKNOWN', 'Predicted POS = .')
# ('Word = the', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = of', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = markings', "Predicted POS = ''")
# ('Word = the', "Predicted POS = ''")
# ('Word = cat', "Predicted POS = ''")
# ('Word = had', "Predicted POS = ''")
# ('Word = had', "Predicted POS = ''")
# ('Word = around', "Predicted POS = ''")
# ('Word = its', "Predicted POS = ''")
# ('Word = eyes', 'Predicted POS = RB')
# ('Word = â\x80\x9c', 'Predicted POS = NNP')
# ('Word = UNKNOWN', 'Predicted POS = NNP')
# ('Word = day', 'Predicted POS = NN')
# ('Word = ?', 'Predicted POS = .')
# ('Word = When', "Predicted POS = ''")
# ('Word = you', "Predicted POS = ''")
# ('Word = could', "Predicted POS = ''")
# ('Word = have', "Predicted POS = ''")
# ('Word = been', "Predicted POS = ''")
# ('Word = celebrating', "Predicted POS = ''")
# ('Word = ?', "Predicted POS = ''")
# ('Word = I', "Predicted POS = ''")
# ('Word = must', "Predicted POS = ''")
# ('Word = have', "Predicted POS = ''")
# ('Word = passed', "Predicted POS = ''")
# ('Word = a', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = and', "Predicted POS = ''")
# ('Word = UNKNOWN', "Predicted POS = ''")
# ('Word = on', "Predicted POS = ''")
# ('Word = my', "Predicted POS = ''")
# ('Word = way', "Predicted POS = ''")
# ('Word = here', 'Predicted POS = RB')
# ('Word = â\x80\x9c', 'Predicted POS = NNP')
# ('Word = Oh', 'Predicted POS = NNP')
# ('Word = yes', 'Predicted POS = RB')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = UNKNOWN', 'Predicted POS = CC')
# ('Word = â\x80\x99', 'Predicted POS = JJ')
# ('Word = s', 'Predicted POS = NN')
# ('Word = celebrating', 'Predicted POS = VBG')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = all', 'Predicted POS = DT')
# ('Word = right', 'Predicted POS = NN')
# ('Word = ,', 'Predicted POS = ,')
# ('Word = â\x80\x9d', 'Predicted POS = NNP')
# ('Word = she', 'Predicted POS = PRP')
# ('Word = said', 'Predicted POS = VBD')
# ('Word = UNKNOWN', 'Predicted POS = IN')

# %%
tags_test = list(data_test.pos)
pos_test = np.zeros((len(tags_test), ), dtype=int)
# print(pos_test)
# print(tags_test)
# print(len(pos_test))
# print(len(tags_test))

for i, val in enumerate(tags_test):
    pos_test[i] = tag2id[val]
len(pos_predict), len(pos_test), len(samples), len(word_test)
# Out:
# (963, 976, 976, 976)

# %%
def reportTest(y_pred, y_test):
    print("The accuracy is {}".format(accuracy_score(y_test, y_pred))) 
    print("The precision is {}".format(precision_score(y_test, y_pred, average='weighted'))) 
    print("The recall is {}".format(recall_score(y_test, y_pred, average='weighted'))) 
    print("The F1-Score is {}".format(f1_score(y_test, y_pred, average='weighted')))

min_length = min(len(pos_predict), len(pos_test))

reportTest(pos_predict[:min_length], pos_test[:min_length])
# Out:
# The accuracy is 0.45586708203530635
# The precision is 0.7590006443683556
# The recall is 0.45586708203530635
# The F1-Score is 0.5592902696546449
